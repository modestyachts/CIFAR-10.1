# %% [markdown]
# ## A notebook for looking through the Tiny Image keywords corresponding to CIFAR-10
#
# ### Setup, data loading, and some checks

# %%
# %load_ext autoreload
# %autoreload 2

from collections import Counter
import json
import os
import sys

repo_root = os.path.join(os.getcwd(), '../code')
sys.path.append(repo_root)

import cifar10

keywords = json.load(open('../other_data/cifar10_keywords_unique.json', 'r'))
assert len(keywords) == 60000

# If we are loading a file with a single keyword per CIFAR-10 image,
# we only have a single dictionary per image (not a list of dictionaries).
# To ensure that the following code has a consistent data format to work with,
# we convert the data format for the unique keyword case to the general data
# format here.
if type(keywords[0]) is dict:
    keywords_tmp = []
    for kw in keywords:
        keywords_tmp.append([kw])
    keywords = keywords_tmp

cifar = cifar10.CIFAR10Data('../other_data/cifar10')

# %% [markdown]
# Example entry

# %%
keywords[0]
# Out:
# [{'nn_index': 40372906,
#   'nn_keyword': 'leptodactylus_pentadactylus',
#   'nn_l2_dst': 0.0}]

# %% [markdown]
# Check how many indices have multiple associated keywords (should be 0 for a unique keywords file).

# %%
indices_with_multiple = []

for ii, kw in enumerate(keywords):
    if len(kw) > 1:
        indices_with_multiple.append(ii)

len(indices_with_multiple)
# Out:
# 0

# %% [markdown]
# ### Compute the keyword counts per class.

# %%
class_counters = {}
for cl in cifar.label_names:
    class_counters[cl] = Counter()
for ii, kws in enumerate(keywords):
    cur_keywords = []
    for kw in kws:
        cur_keywords.append(kw['nn_keyword'])
    class_counters[cifar.label_names[cifar.all_labels[ii]]].update(cur_keywords)

# %% [markdown]
# ### Show the top k keywords for each class

# %%
top_k = 100

print_csv = True


all_keywords = []
for class_name, counter in class_counters.items():
    total_count = 0
    for count in counter.values():
        total_count += count
    top_k_count = 0
    cur_keywords = []
    for keyword, count in counter.most_common(top_k):
        top_k_count += count
        cur_keywords.append(keyword)
    all_keywords.extend(cur_keywords)
    print('{}  (keyword count sum: {}, top {} keyword count sum: {}, number of keywords: {})'.format(class_name, total_count, top_k, top_k_count, len(counter)))
    for keyword, count in counter.most_common(top_k):
        print('  {}: {}'.format(keyword, count))
    if print_csv:
        print('')
        print('  Comma-separated list of keywords: {}'.format(','.join(cur_keywords)))
    print('\n')
if print_csv:
    print('Comma-separated list of all keywords: {}'.format(','.join(all_keywords)))
# Out:
# airplane  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 29)
#   stealth_bomber: 587
#   airbus: 537
#   stealth_fighter: 474
#   fighter_aircraft: 466
#   biplane: 443
#   attack_aircraft: 401
#   airliner: 391
#   jetliner: 345
#   monoplane: 335
#   dive_bomber: 314
#   jumbo_jet: 314
#   twinjet: 311
#   jumbojet: 182
#   propeller_plane: 167
#   fighter: 133
#   amphibious_aircraft: 119
#   multiengine_airplane: 105
#   plane: 92
#   seaplane: 82
#   reconnaissance_plane: 53
#   airplane: 38
#   floatplane: 31
#   aeroplane: 23
#   hangar_queen: 19
#   bomber: 15
#   multiengine_plane: 14
#   kamikaze: 4
#   interceptor: 4
#   hydroplane: 1
#
#   Comma-separated list of keywords: stealth_bomber,airbus,stealth_fighter,fighter_aircraft,biplane,attack_aircraft,airliner,jetliner,monoplane,dive_bomber,jumbo_jet,twinjet,jumbojet,propeller_plane,fighter,amphibious_aircraft,multiengine_airplane,plane,seaplane,reconnaissance_plane,airplane,floatplane,aeroplane,hangar_queen,bomber,multiengine_plane,kamikaze,interceptor,hydroplane
#
#
# automobile  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 26)
#   coupe: 777
#   convertible: 720
#   station_wagon: 591
#   automobile: 541
#   car: 502
#   auto: 478
#   compact_car: 461
#   shooting_brake: 376
#   estate_car: 358
#   police_cruiser: 276
#   wagon: 251
#   motorcar: 238
#   taxi: 99
#   beach_wagon: 80
#   compact: 63
#   cruiser: 47
#   ambulance: 41
#   cab: 40
#   funny_wagon: 32
#   taxicab: 11
#   minicab: 9
#   station_waggon: 5
#   jalopy: 1
#   gypsy_cab: 1
#   machine: 1
#   bus: 1
#
#   Comma-separated list of keywords: coupe,convertible,station_wagon,automobile,car,auto,compact_car,shooting_brake,estate_car,police_cruiser,wagon,motorcar,taxi,beach_wagon,compact,cruiser,ambulance,cab,funny_wagon,taxicab,minicab,station_waggon,jalopy,gypsy_cab,machine,bus
#
#
# bird  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 47)
#   bird: 535
#   cassowary: 514
#   wagtail: 444
#   ostrich: 415
#   sparrow: 330
#   passerine: 326
#   emu: 307
#   struthio_camelus: 301
#   accentor: 289
#   pipit: 281
#   honey_eater: 226
#   dunnock: 220
#   finch: 164
#   nandu: 157
#   alauda_arvensis: 151
#   dromaius_novaehollandiae: 132
#   anthus_pratensis: 128
#   prunella_modularis: 123
#   rhea_americana: 117
#   lark: 103
#   meadow_pipit: 80
#   flying_bird: 76
#   apteryx: 62
#   bird_of_passage: 62
#   songbird: 61
#   flightless_bird: 58
#   rhea: 54
#   cock: 51
#   hen: 35
#   skylark: 27
#   kiwi: 26
#   night_bird: 24
#   ratite: 23
#   emu_novaehollandiae: 23
#   elephant_bird: 17
#   gamecock: 15
#   hedge_sparrow: 14
#   pterocnemia_pennata: 14
#   fighting_cock: 4
#   carinate: 2
#   ratite_bird: 2
#   giant_moa: 2
#   oscine: 1
#   moa: 1
#   night_raven: 1
#   aepyornis: 1
#   honeysucker: 1
#
#   Comma-separated list of keywords: bird,cassowary,wagtail,ostrich,sparrow,passerine,emu,struthio_camelus,accentor,pipit,honey_eater,dunnock,finch,nandu,alauda_arvensis,dromaius_novaehollandiae,anthus_pratensis,prunella_modularis,rhea_americana,lark,meadow_pipit,flying_bird,apteryx,bird_of_passage,songbird,flightless_bird,rhea,cock,hen,skylark,kiwi,night_bird,ratite,emu_novaehollandiae,elephant_bird,gamecock,hedge_sparrow,pterocnemia_pennata,fighting_cock,carinate,ratite_bird,giant_moa,oscine,moa,night_raven,aepyornis,honeysucker
#
#
# cat  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 12)
#   tabby_cat: 1111
#   tabby: 901
#   domestic_cat: 840
#   cat: 753
#   house_cat: 474
#   felis_catus: 413
#   mouser: 379
#   felis_domesticus: 373
#   tomcat: 292
#   true_cat: 284
#   alley_cat: 178
#   queen: 2
#
#   Comma-separated list of keywords: tabby_cat,tabby,domestic_cat,cat,house_cat,felis_catus,mouser,felis_domesticus,tomcat,true_cat,alley_cat,queen
#
#
# deer  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 38)
#   elk: 461
#   fallow_deer: 453
#   capreolus_capreolus: 428
#   cervus_elaphus: 367
#   deer: 360
#   mule_deer: 322
#   odocoileus_hemionus: 304
#   muntjac: 303
#   roe_deer: 295
#   fawn: 292
#   alces_alces: 218
#   wapiti: 213
#   american_elk: 212
#   moose: 210
#   red_deer: 172
#   rangifer_tarandus: 168
#   sika: 130
#   caribou: 126
#   rangifer_caribou: 123
#   woodland_caribou: 110
#   barking_deer: 104
#   sambar: 90
#   dama_dama: 89
#   cervus_sika: 88
#   stag: 73
#   cervus_unicolor: 53
#   japanese_deer: 51
#   musk_deer: 43
#   barren_ground_caribou: 40
#   reindeer: 26
#   european_elk: 25
#   brocket: 24
#   roebuck: 8
#   sambur: 7
#   burro_deer: 5
#   greenland_caribou: 3
#   cervid: 3
#   rangifer_arcticus: 1
#
#   Comma-separated list of keywords: elk,fallow_deer,capreolus_capreolus,cervus_elaphus,deer,mule_deer,odocoileus_hemionus,muntjac,roe_deer,fawn,alces_alces,wapiti,american_elk,moose,red_deer,rangifer_tarandus,sika,caribou,rangifer_caribou,woodland_caribou,barking_deer,sambar,dama_dama,cervus_sika,stag,cervus_unicolor,japanese_deer,musk_deer,barren_ground_caribou,reindeer,european_elk,brocket,roebuck,sambur,burro_deer,greenland_caribou,cervid,rangifer_arcticus
#
#
# dog  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 22)
#   pekingese: 767
#   maltese: 586
#   puppy: 545
#   chihuahua: 486
#   dog: 411
#   pekinese: 388
#   toy_spaniel: 368
#   mongrel: 306
#   mutt: 276
#   maltese_dog: 232
#   japanese_spaniel: 231
#   toy_dog: 218
#   blenheim_spaniel: 207
#   domestic_dog: 197
#   lapdog: 179
#   canis_familiaris: 161
#   peke: 147
#   king_charles_spaniel: 95
#   toy: 86
#   english_toy_spaniel: 54
#   feist: 38
#   cur: 22
#
#   Comma-separated list of keywords: pekingese,maltese,puppy,chihuahua,dog,pekinese,toy_spaniel,mongrel,mutt,maltese_dog,japanese_spaniel,toy_dog,blenheim_spaniel,domestic_dog,lapdog,canis_familiaris,peke,king_charles_spaniel,toy,english_toy_spaniel,feist,cur
#
#
# frog  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 60)
#   bufo_bufo: 608
#   leopard_frog: 388
#   bufo_viridis: 337
#   rana_temporaria: 316
#   bufo_americanus: 273
#   green_frog: 271
#   toad: 267
#   rana_catesbeiana: 258
#   bufo_marinus: 250
#   bullfrog: 207
#   frog: 203
#   american_toad: 174
#   spadefoot: 171
#   toad_frog: 164
#   pickerel_frog: 162
#   rana_pipiens: 160
#   western_toad: 141
#   spring_frog: 133
#   grass_frog: 116
#   rana_clamitans: 105
#   crapaud: 99
#   bufo_calamita: 97
#   bufo: 95
#   alytes_obstetricans: 89
#   true_frog: 80
#   texas_toad: 76
#   anuran: 73
#   barking_frog: 70
#   tailed_frog: 58
#   bufo_boreas: 57
#   natterjack: 55
#   bufo_debilis: 54
#   southwestern_toad: 52
#   european_toad: 38
#   midwife_toad: 36
#   cascades_frog: 32
#   leptodactylus_pentadactylus: 31
#   yosemite_toad: 23
#   bufo_speciosus: 21
#   bufo_microscaphus: 20
#   leptodactylid: 19
#   rana_cascadae: 19
#   true_toad: 16
#   rana_palustris: 13
#   robber_frog: 13
#   tailed_toad: 12
#   american_green_toad: 10
#   south_american_bullfrog: 6
#   goliath_frog: 5
#   ranid: 5
#   tarahumara_frog: 5
#   bufo_canorus: 3
#   ribbed_toad: 3
#   bell_toad: 3
#   rana_tarahumarae: 2
#   leptodactylid_frog: 2
#   hylactophryne_augusti: 1
#   spring_peeper: 1
#   tree_toad: 1
#   wood-frog: 1
#
#   Comma-separated list of keywords: bufo_bufo,leopard_frog,bufo_viridis,rana_temporaria,bufo_americanus,green_frog,toad,rana_catesbeiana,bufo_marinus,bullfrog,frog,american_toad,spadefoot,toad_frog,pickerel_frog,rana_pipiens,western_toad,spring_frog,grass_frog,rana_clamitans,crapaud,bufo_calamita,bufo,alytes_obstetricans,true_frog,texas_toad,anuran,barking_frog,tailed_frog,bufo_boreas,natterjack,bufo_debilis,southwestern_toad,european_toad,midwife_toad,cascades_frog,leptodactylus_pentadactylus,yosemite_toad,bufo_speciosus,bufo_microscaphus,leptodactylid,rana_cascadae,true_toad,rana_palustris,robber_frog,tailed_toad,american_green_toad,south_american_bullfrog,goliath_frog,ranid,tarahumara_frog,bufo_canorus,ribbed_toad,bell_toad,rana_tarahumarae,leptodactylid_frog,hylactophryne_augusti,spring_peeper,tree_toad,wood-frog
#
#
# horse  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 40)
#   arabian: 677
#   lipizzan: 613
#   broodmare: 588
#   quarter_horse: 491
#   gelding: 441
#   stud_mare: 419
#   lippizaner: 370
#   tennessee_walker: 282
#   appaloosa: 266
#   dawn_horse: 250
#   tennessee_walking_horse: 238
#   stallion: 215
#   lippizan: 215
#   walking_horse: 145
#   riding_horse: 118
#   saddle_horse: 108
#   male_horse: 81
#   cow_pony: 65
#   female_horse: 60
#   buckskin: 57
#   cavalry_horse: 52
#   american_saddle_horse: 34
#   plantation_walking_horse: 32
#   arab: 29
#   mare: 27
#   studhorse: 25
#   horse: 18
#   prancer: 13
#   roan: 12
#   equus_caballus: 10
#   stud: 9
#   remount: 8
#   warhorse: 8
#   morgan: 6
#   steed: 5
#   stable_companion: 5
#   palfrey: 3
#   mesohippus: 2
#   stablemate: 2
#   eohippus: 1
#
#   Comma-separated list of keywords: arabian,lipizzan,broodmare,quarter_horse,gelding,stud_mare,lippizaner,tennessee_walker,appaloosa,dawn_horse,tennessee_walking_horse,stallion,lippizan,walking_horse,riding_horse,saddle_horse,male_horse,cow_pony,female_horse,buckskin,cavalry_horse,american_saddle_horse,plantation_walking_horse,arab,mare,studhorse,horse,prancer,roan,equus_caballus,stud,remount,warhorse,morgan,steed,stable_companion,palfrey,mesohippus,stablemate,eohippus
#
#
# ship  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 87)
#   passenger_ship: 477
#   boat: 391
#   cargo_ship: 294
#   cargo_vessel: 244
#   ship: 222
#   speedboat: 197
#   freighter: 193
#   container_ship: 187
#   pilot_boat: 184
#   pontoon: 181
#   oil_tanker: 179
#   cabin_cruiser: 178
#   sea_boat: 175
#   police_boat: 158
#   powerboat: 154
#   lightship: 137
#   hospital_ship: 131
#   pleasure_boat: 125
#   dredger: 123
#   guard_boat: 119
#   container_vessel: 113
#   banana_boat: 112
#   merchant_ship: 111
#   liberty_ship: 91
#   scow: 89
#   motorboat: 88
#   houseboat: 78
#   tanker: 74
#   containership: 68
#   iceboat: 68
#   icebreaker: 63
#   packet_boat: 60
#   tank_ship: 58
#   barge: 58
#   tugboat: 51
#   pleasure_craft: 51
#   ferryboat: 50
#   fireboat: 50
#   hydrofoil: 42
#   racing_boat: 41
#   supertanker: 40
#   ferry: 39
#   river_boat: 38
#   norfolk_wherry: 35
#   merchantman: 33
#   abandoned_ship: 31
#   minesweeper: 26
#   cruiser: 24
#   tug: 24
#   rowboat: 23
#   lifeboat: 20
#   flatboat: 18
#   mackinaw_boat: 18
#   outboard_motorboat: 12
#   cattle_boat: 12
#   outboard: 12
#   small_boat: 11
#   minelayer: 10
#   gunboat: 10
#   liner: 10
#   bumboat: 9
#   mackinaw: 9
#   canal_boat: 8
#   rowing_boat: 6
#   mail_boat: 6
#   steamboat: 6
#   ocean_liner: 5
#   wherry: 5
#   skiff: 4
#   showboat: 4
#   narrow_boat: 3
#   keelboat: 3
#   longboat: 2
#   dinghy: 2
#   flagship: 2
#   narrowboat: 2
#   mayflower: 2
#   gondola: 2
#   shipping_office: 1
#   mailboat: 1
#   whaleboat: 1
#   water_scooter: 1
#   packet: 1
#   sampan: 1
#   replenishment: 1
#   cattleship: 1
#   hulk: 1
#
#   Comma-separated list of keywords: passenger_ship,boat,cargo_ship,cargo_vessel,ship,speedboat,freighter,container_ship,pilot_boat,pontoon,oil_tanker,cabin_cruiser,sea_boat,police_boat,powerboat,lightship,hospital_ship,pleasure_boat,dredger,guard_boat,container_vessel,banana_boat,merchant_ship,liberty_ship,scow,motorboat,houseboat,tanker,containership,iceboat,icebreaker,packet_boat,tank_ship,barge,tugboat,pleasure_craft,ferryboat,fireboat,hydrofoil,racing_boat,supertanker,ferry,river_boat,norfolk_wherry,merchantman,abandoned_ship,minesweeper,cruiser,tug,rowboat,lifeboat,flatboat,mackinaw_boat,outboard_motorboat,cattle_boat,outboard,small_boat,minelayer,gunboat,liner,bumboat,mackinaw,canal_boat,rowing_boat,mail_boat,steamboat,ocean_liner,wherry,skiff,showboat,narrow_boat,keelboat,longboat,dinghy,flagship,narrowboat,mayflower,gondola,shipping_office,mailboat,whaleboat,water_scooter,packet,sampan,replenishment,cattleship,hulk
#
#
# truck  (keyword count sum: 6000, top 100 keyword count sum: 6000, number of keywords: 42)
#   dump_truck: 544
#   trucking_rig: 456
#   tipper_truck: 420
#   truck: 392
#   delivery_truck: 373
#   camion: 350
#   fire_truck: 328
#   lorry: 320
#   garbage_truck: 319
#   aerial_ladder_truck: 211
#   tractor_trailer: 209
#   moving_van: 194
#   fire_engine: 169
#   dumper: 166
#   wrecker: 162
#   trailer_truck: 157
#   tipper: 156
#   ladder_truck: 144
#   articulated_lorry: 142
#   tipper_lorry: 118
#   semi: 100
#   tow_truck: 69
#   sound_truck: 68
#   delivery_van: 62
#   bookmobile: 60
#   car_transporter: 52
#   tip_truck: 49
#   transporter: 39
#   pantechnicon: 38
#   tandem_trailer: 35
#   dustcart: 33
#   laundry_truck: 17
#   panel_truck: 17
#   rig: 16
#   motortruck: 4
#   tow_car: 4
#   milk_float: 2
#   mack: 1
#   van: 1
#   tractor: 1
#   pickup: 1
#   pickup_truck: 1
#
#   Comma-separated list of keywords: dump_truck,trucking_rig,tipper_truck,truck,delivery_truck,camion,fire_truck,lorry,garbage_truck,aerial_ladder_truck,tractor_trailer,moving_van,fire_engine,dumper,wrecker,trailer_truck,tipper,ladder_truck,articulated_lorry,tipper_lorry,semi,tow_truck,sound_truck,delivery_van,bookmobile,car_transporter,tip_truck,transporter,pantechnicon,tandem_trailer,dustcart,laundry_truck,panel_truck,rig,motortruck,tow_car,milk_float,mack,van,tractor,pickup,pickup_truck
#
#
# Comma-separated list of all keywords: stealth_bomber,airbus,stealth_fighter,fighter_aircraft,biplane,attack_aircraft,airliner,jetliner,monoplane,dive_bomber,jumbo_jet,twinjet,jumbojet,propeller_plane,fighter,amphibious_aircraft,multiengine_airplane,plane,seaplane,reconnaissance_plane,airplane,floatplane,aeroplane,hangar_queen,bomber,multiengine_plane,kamikaze,interceptor,hydroplane,coupe,convertible,station_wagon,automobile,car,auto,compact_car,shooting_brake,estate_car,police_cruiser,wagon,motorcar,taxi,beach_wagon,compact,cruiser,ambulance,cab,funny_wagon,taxicab,minicab,station_waggon,jalopy,gypsy_cab,machine,bus,bird,cassowary,wagtail,ostrich,sparrow,passerine,emu,struthio_camelus,accentor,pipit,honey_eater,dunnock,finch,nandu,alauda_arvensis,dromaius_novaehollandiae,anthus_pratensis,prunella_modularis,rhea_americana,lark,meadow_pipit,flying_bird,apteryx,bird_of_passage,songbird,flightless_bird,rhea,cock,hen,skylark,kiwi,night_bird,ratite,emu_novaehollandiae,elephant_bird,gamecock,hedge_sparrow,pterocnemia_pennata,fighting_cock,carinate,ratite_bird,giant_moa,oscine,moa,night_raven,aepyornis,honeysucker,tabby_cat,tabby,domestic_cat,cat,house_cat,felis_catus,mouser,felis_domesticus,tomcat,true_cat,alley_cat,queen,elk,fallow_deer,capreolus_capreolus,cervus_elaphus,deer,mule_deer,odocoileus_hemionus,muntjac,roe_deer,fawn,alces_alces,wapiti,american_elk,moose,red_deer,rangifer_tarandus,sika,caribou,rangifer_caribou,woodland_caribou,barking_deer,sambar,dama_dama,cervus_sika,stag,cervus_unicolor,japanese_deer,musk_deer,barren_ground_caribou,reindeer,european_elk,brocket,roebuck,sambur,burro_deer,greenland_caribou,cervid,rangifer_arcticus,pekingese,maltese,puppy,chihuahua,dog,pekinese,toy_spaniel,mongrel,mutt,maltese_dog,japanese_spaniel,toy_dog,blenheim_spaniel,domestic_dog,lapdog,canis_familiaris,peke,king_charles_spaniel,toy,english_toy_spaniel,feist,cur,bufo_bufo,leopard_frog,bufo_viridis,rana_temporaria,bufo_americanus,green_frog,toad,rana_catesbeiana,bufo_marinus,bullfrog,frog,american_toad,spadefoot,toad_frog,pickerel_frog,rana_pipiens,western_toad,spring_frog,grass_frog,rana_clamitans,crapaud,bufo_calamita,bufo,alytes_obstetricans,true_frog,texas_toad,anuran,barking_frog,tailed_frog,bufo_boreas,natterjack,bufo_debilis,southwestern_toad,european_toad,midwife_toad,cascades_frog,leptodactylus_pentadactylus,yosemite_toad,bufo_speciosus,bufo_microscaphus,leptodactylid,rana_cascadae,true_toad,rana_palustris,robber_frog,tailed_toad,american_green_toad,south_american_bullfrog,goliath_frog,ranid,tarahumara_frog,bufo_canorus,ribbed_toad,bell_toad,rana_tarahumarae,leptodactylid_frog,hylactophryne_augusti,spring_peeper,tree_toad,wood-frog,arabian,lipizzan,broodmare,quarter_horse,gelding,stud_mare,lippizaner,tennessee_walker,appaloosa,dawn_horse,tennessee_walking_horse,stallion,lippizan,walking_horse,riding_horse,saddle_horse,male_horse,cow_pony,female_horse,buckskin,cavalry_horse,american_saddle_horse,plantation_walking_horse,arab,mare,studhorse,horse,prancer,roan,equus_caballus,stud,remount,warhorse,morgan,steed,stable_companion,palfrey,mesohippus,stablemate,eohippus,passenger_ship,boat,cargo_ship,cargo_vessel,ship,speedboat,freighter,container_ship,pilot_boat,pontoon,oil_tanker,cabin_cruiser,sea_boat,police_boat,powerboat,lightship,hospital_ship,pleasure_boat,dredger,guard_boat,container_vessel,banana_boat,merchant_ship,liberty_ship,scow,motorboat,houseboat,tanker,containership,iceboat,icebreaker,packet_boat,tank_ship,barge,tugboat,pleasure_craft,ferryboat,fireboat,hydrofoil,racing_boat,supertanker,ferry,river_boat,norfolk_wherry,merchantman,abandoned_ship,minesweeper,cruiser,tug,rowboat,lifeboat,flatboat,mackinaw_boat,outboard_motorboat,cattle_boat,outboard,small_boat,minelayer,gunboat,liner,bumboat,mackinaw,canal_boat,rowing_boat,mail_boat,steamboat,ocean_liner,wherry,skiff,showboat,narrow_boat,keelboat,longboat,dinghy,flagship,narrowboat,mayflower,gondola,shipping_office,mailboat,whaleboat,water_scooter,packet,sampan,replenishmen ...

# %% [markdown]
# ## Print information for images with multiple keywords

# %%
for ii in indices_with_multiple[:40]:
    cur_class = keywords[ii][0]['cifar10_label']
    kws = []
    for tmp in keywords[ii]:
        kws.append(tmp['nn_keyword'])
    print('\nindex {}  class {}'.format(ii, cur_class))
    for kw in kws:
        print('  {}: {}'.format(kw, class_counters[cur_class][kw]))
